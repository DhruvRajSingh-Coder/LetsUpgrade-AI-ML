# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvRajSingh-Coder/LetsUpgrade-AI-ML/blob/master/Day_7_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1:
# Attach the dataset and mentioned problem statement below,
# ● A sizable department has to be maintained, for the purposes of recruiting new talent.
# ● More often than not, the new employees have to be trained for the job and/or given time to
# acclimatize themselves to the company.
# ● Hence, the management has contracted an HR analytics firm to understand what factors they
# should focus on, in order to curb attrition.
# ● In other words, they want to know what changes they should make to their workplace, in order to
# get most of their employees to stay.
# ● Also, they want to know which of these variables is most important and needs to be addressed
# right away.

# %%
 import pandas as pd
Data=pd.read_csv("https://raw.githubusercontent.com/LetsUpgrade/AI-ML-July-2020/master/Day-7/Assignment/general_data.csv")
Data.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0   51        No  ...                       0                    0
# 1   31       Yes  ...                       1                    4
# 2   32        No  ...                       0                    3
# 3   38        No  ...                       7                    5
# 4   32        No  ...                       0                    4
#
# [5 rows x 24 columns]

# %%
Data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
Data.mean()
# Out:
# Age                           36.923810
# DistanceFromHome               9.192517
# Education                      2.912925
# EmployeeCount                  1.000000
# EmployeeID                  2205.500000
# JobLevel                       2.063946
# MonthlyIncome              65029.312925
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# StandardHours                  8.000000
# StockOptionLevel               0.793878
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %%
Data.median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2205.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
Data.mode().head(1)
# Out:
#     Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0  35.0        No  ...                     0.0                  2.0
#
# [1 rows x 24 columns]

# %%
Data.isnull()
# Out:
#         Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0     False      False  ...                    False                 False
# 1     False      False  ...                    False                 False
# 2     False      False  ...                    False                 False
# 3     False      False  ...                    False                 False
# 4     False      False  ...                    False                 False
# ...     ...        ...  ...                      ...                   ...
# 4405  False      False  ...                    False                 False
# 4406  False      False  ...                    False                 False
# 4407  False      False  ...                    False                 False
# 4408  False      False  ...                    False                 False
# 4409  False      False  ...                    False                 False
#
# [4410 rows x 24 columns]

# %%
Data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
Data.drop_duplicates()
# Out:
#       Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51        No  ...                       0                    0
# 1      31       Yes  ...                       1                    4
# 2      32        No  ...                       0                    3
# 3      38        No  ...                       7                    5
# 4      32        No  ...                       0                    4
# ...   ...       ...  ...                     ...                  ...
# 4405   42        No  ...                       0                    2
# 4406   29        No  ...                       0                    2
# 4407   25        No  ...                       1                    2
# 4408   42        No  ...                       7                    8
# 4409   40        No  ...                       3                    9
#
# [4410 rows x 24 columns]

# %%
Data.describe()
# Out:
#                Age  ...  YearsWithCurrManager
# count  4410.000000  ...           4410.000000
# mean     36.923810  ...              4.123129
# std       9.133301  ...              3.567327
# min      18.000000  ...              0.000000
# 25%      30.000000  ...              2.000000
# 50%      36.000000  ...              3.000000
# 75%      43.000000  ...              7.000000
# max      60.000000  ...             17.000000
#
# [8 rows x 16 columns]

# %%
Data.var()
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 1.621042e+06
# JobLevel                   1.224760e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# StandardHours              0.000000e+00
# StockOptionLevel           7.257053e-01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
Data.skew()
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# JobLevel                   1.024703
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# StandardHours              0.000000
# StockOptionLevel           0.968321
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
Data.kurt()
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# EmployeeCount              0.000000
# EmployeeID                -1.200000
# JobLevel                   0.395525
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# StandardHours              0.000000
# StockOptionLevel           0.361086
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
Data.std()
# Out:
# Age                            9.133301
# DistanceFromHome               8.105026
# Education                      1.023933
# EmployeeCount                  0.000000
# EmployeeID                  1273.201673
# JobLevel                       1.106689
# MonthlyIncome              47068.888559
# NumCompaniesWorked             2.498887
# PercentSalaryHike              3.659108
# StandardHours                  0.000000
# StockOptionLevel               0.851883
# TotalWorkingYears              7.782222
# TrainingTimesLastYear          1.288978
# YearsAtCompany                 6.125135
# YearsSinceLastPromotion        3.221699
# YearsWithCurrManager           3.567327
# dtype: float64

# %%
 from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Data["Attrition"]=le.fit_transform(Data["Attrition"])
Data.drop('EmployeeID',axis=1,inplace=True)
Data.head(4410)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51          0  ...                       0                    0
# 1      31          1  ...                       1                    4
# 2      32          0  ...                       0                    3
# 3      38          0  ...                       7                    5
# 4      32          0  ...                       0                    4
# ...   ...        ...  ...                     ...                  ...
# 4405   42          0  ...                       0                    2
# 4406   29          0  ...                       0                    2
# 4407   25          0  ...                       1                    2
# 4408   42          0  ...                       7                    8
# 4409   40          0  ...                       3                    9
#
# [4410 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(Data.Age)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e453be10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e44cf860>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e44db320>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e44cff60>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e44cf160>,
#   <matplotlib.lines.Line2D at 0x7fe6e44cf4e0>]}

# %%
plt.boxplot(Data.DistanceFromHome)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e4007080>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e4007a90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e4013550>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e40131d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e4007390>,
#   <matplotlib.lines.Line2D at 0x7fe6e4007710>]}

# %%
plt.boxplot(Data.Education)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e3fee710>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e3f7c160>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e3f7cbe0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e3f7c860>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e3feea20>,
#   <matplotlib.lines.Line2D at 0x7fe6e3feeda0>]}

# %%
plt.boxplot(Data.MonthlyIncome)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e3f5dc18>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e3f6b668>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e3f76128>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e3f6bd68>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e3f5df28>,
#   <matplotlib.lines.Line2D at 0x7fe6e3f6b2e8>]}

# %%
plt.boxplot(Data.YearsSinceLastPromotion)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e3ecc5f8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e3eda048>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e3edaac8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e3eda748>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e3ecc908>,
#   <matplotlib.lines.Line2D at 0x7fe6e3eccc88>]}

# %%
plt.boxplot(Data.PercentSalaryHike)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe6e3dc05f8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe6e3dcf048>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe6e3dcfac8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe6e3dcf748>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe6e3dc0908>,
#   <matplotlib.lines.Line2D at 0x7fe6e3dc0c88>]}

# %% [markdown]
# After analysis from above data,in order reduce attrition HR must take the following steps:
# 1.There are lot of employees of age group 30-40 which should be brought down to 20-30 because younger people are more curious and are ready to work hard for long term which would be a significant step in order to reduce attrition.
# 2.Employees must be hired who are located near the office so that they don't get tired of travelling and could travel more quickly and safely to the office along with saving time.
# 3.Company should provide better Salary hike to retain few employees
# Company should keep a check on Research& Development department and also Sales department as more employees are leaving from those department.
# 4.Company should have a check on employees who are not traveling at all like are leaving the company more.
# 5.People With bachelor's degree and master's degree tend to have more Attrition so company can focus on them and give a proper treatment such as giving them promotion and providing them with good amount of work which will enable them to reach new heights.
# 6.Research & Development department has a significantly more attrition rate compared to other departments.
# 7.People who travel rarely are leaving the company more i.e attrtion rate is comparatively high for them.
# 8.Male Attrition rate is higher compared to female.
# 9.People with Job Role Research Scientist and Sales Executive have more attrition rate.
# 10.Company can occasionally take the employees to a trip to refresh their minds so that they get attached to the company for a long time.
